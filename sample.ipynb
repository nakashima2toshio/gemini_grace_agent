# %%
import sys
import os

# 🔧 Jupyter Notebook環境に対応したパス取得
# __file__ が定義されていない場合は os.getcwd() を使用します
try:
    base_path = os.path.dirname(os.path.abspath(__file__))
except NameError:
    base_path = os.getcwd()

# 🔧 プロジェクトルートをPythonパスに追加（現在のディレクトリの2階層上を想定）
project_root_path = os.path.dirname(os.path.dirname(base_path))
sys.path.insert(0, project_root_path)

# 🔧 プロジェクトルートの絶対パスを取得
PROJECT_ROOT = os.path.join(project_root_path, "PycharmProjects/gemini_grace_agent")
print('PROJECT_ROOT =', PROJECT_ROOT )

# /Users/nakashima_toshio/PycharmProjects/gemini_grace_agent
# Out:
# PROJECT_ROOT = /Users/nakashima_toshio/PycharmProjects/gemini_grace_agent
